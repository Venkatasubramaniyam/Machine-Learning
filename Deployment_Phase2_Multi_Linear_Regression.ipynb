# %%
import pickle

# %%
loaded_model=pickle.load(open("finalized_model_multilinear.sav",'rb'))
result=loaded_model.predict([[165349.20,136897.80,471784.10,0,1]])
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[192239.66787833]])

# %%
result=loaded_model.predict([[162597.70,151377.59,443898.53,0,0]])
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[189331.24795042]])

# %%
result=loaded_model.predict([[28663.76,127056.21,201126.82,1,0]])
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[75609.96767583]])
