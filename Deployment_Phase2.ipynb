# %%
#Deployment Phase2
#26777 bias value - when we use 0 it's a  origin / intercept value
#y=9360X+26777(origin or minimum value)
#y=9360(0)+26777
#for 0 years of exp, we get answer from bias (orgin / model initial value)

# %%
import pickle

# %%
loaded_model=pickle.load(open("finalized_model_linear.sav",'rb'))
result=loaded_model.predict([[0]])
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[26777.3913412]])
